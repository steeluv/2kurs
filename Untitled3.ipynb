# %% [markdown]
# #  Анализ по датасету "car price"
# ****
# *****
# *****
# #### работу выполнила Еникеева Виолетта
# ***

# %% [markdown]
# ## Устанавливаем "pandas"
# ****************************

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\steluv\pycharmprojects\pythonproject8\venv\lib\site-packages (2.1.1)
# Requirement already satisfied: numpy>=1.23.2 in c:\users\steluv\pycharmprojects\pythonproject8\venv\lib\site-packages (from pandas) (1.26.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\steluv\pycharmprojects\pythonproject8\venv\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\steluv\pycharmprojects\pythonproject8\venv\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\steluv\pycharmprojects\pythonproject8\venv\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\steluv\pycharmprojects\pythonproject8\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %% [markdown]
# ## Присваиваем значению "car" путь до нашего датасета
#
# ************

# %%
car = pd.read_csv(r"C:\Users\Steluv\PycharmProjects\pythonProject8\car_price.csv")

# %% [markdown]
# ## Теперь удаляем столбец "Unnamed", который не представляет особого значения
# **********

# %%
car.drop('Unnamed: 0' , axis=1 , inplace=True)

# %% [markdown]
# ##### (Данной командой, мы можем поменять названия столбцов (для нашего удобства))
# ***

# %%
new_col = ["Classes" , "Old Price" , "Price Change" , "New Price" , "change date"]

# %%
car.columns = new_col

# %% [markdown]
# ## Выводим табличку "car"
# ***

# %%
car
# Out:
#                                        Classes      Old Price  \
# 0          Peugeot 5008 A/T / Active Pack 2023  1,029,990 EGP
# 1       Ssang Yong Tivoli XLV A/T / Style 2023    675,000 EGP
# 2     Ssang Yong Tivoli XLV A/T / Comfort 2023    605,000 EGP
# 3      Ssang Yong Tivoli A/T / Style Plus 2023    665,000 EGP
# 4         Ssang Yong Tivoli A/T / Comfort 2023    590,000 EGP
# ...                                        ...            ...
# 3499                Lexus LX 570 Automtic 2020  5,600,000 EGP
# 3500                Lexus ES 350 Automtic 2020  2,650,000 EGP
# 3501                Lexus LX 570 Automtic 2020  5,800,000 EGP
# 3502              Porsche Cayenne A/T / S 2020  2,262,876 EGP
# 3503          Porsche Cayenne A/T / Coupe 2020  2,078,727 EGP
#
#                     Price Change      New Price change date
# 0       trending_up +110,000 EGP  1,139,990 EGP   1/19/2023
# 1         trending_up +5,000 EGP    680,000 EGP   1/19/2023
# 2       trending_up +185,000 EGP    790,000 EGP   1/19/2023
# 3       trending_up +185,000 EGP    850,000 EGP   1/19/2023
# 4       trending_up +170,000 EGP    760,000 EGP   1/19/2023
# ...                          ...            ...         ...
# 3499  trending_down -350,000 EGP  5,250,000 EGP   5/18/2020
# 3500    trending_up +180,000 EGP  2,830,000 EGP  12/18/2019
# 3501  trending_down -200,000 EGP  5,600,000 EGP  12/15/2019
# 3502    trending_up +125,124 EGP  2,388,000 EGP  10/15/2019
# 3503    trending_up +184,149 EGP  2,262,876 EGP  10/14/2019
#
# [3504 rows x 5 columns]

# %% [markdown]
# ## С помощью данной функции мы удалили все лишние запятые в значениях столбцов "Old Price" и "New Price"
#
# ***

# %%
def to_int (column ):
    car[column] = car[column].astype(str).replace(r'\D', '', regex=True)
    for i in range(len(car[column])):
        car[column][i] = car[column][i].replace("," , "")

# %%
to_int("Old Price")
to_int("New Price")

# %%
car.loc[:, "Old Price"] = car["Old Price"].astype(int)
car.loc[:, "New Price"] = car["New Price"].astype(int)

# %%
car
# Out:
#                                        Classes Old Price  \
# 0          Peugeot 5008 A/T / Active Pack 2023   1029990
# 1       Ssang Yong Tivoli XLV A/T / Style 2023    675000
# 2     Ssang Yong Tivoli XLV A/T / Comfort 2023    605000
# 3      Ssang Yong Tivoli A/T / Style Plus 2023    665000
# 4         Ssang Yong Tivoli A/T / Comfort 2023    590000
# ...                                        ...       ...
# 3499                Lexus LX 570 Automtic 2020   5600000
# 3500                Lexus ES 350 Automtic 2020   2650000
# 3501                Lexus LX 570 Automtic 2020   5800000
# 3502              Porsche Cayenne A/T / S 2020   2262876
# 3503          Porsche Cayenne A/T / Coupe 2020   2078727
#
#                     Price Change New Price change date
# 0       trending_up +110,000 EGP   1139990   1/19/2023
# 1         trending_up +5,000 EGP    680000   1/19/2023
# 2       trending_up +185,000 EGP    790000   1/19/2023
# 3       trending_up +185,000 EGP    850000   1/19/2023
# 4       trending_up +170,000 EGP    760000   1/19/2023
# ...                          ...       ...         ...
# 3499  trending_down -350,000 EGP   5250000   5/18/2020
# 3500    trending_up +180,000 EGP   2830000  12/18/2019
# 3501  trending_down -200,000 EGP   5600000  12/15/2019
# 3502    trending_up +125,124 EGP   2388000  10/15/2019
# 3503    trending_up +184,149 EGP   2262876  10/14/2019
#
# [3504 rows x 5 columns]

# %% [markdown]
# ## Выведем первые 300 элементов:
# ***

# %%
car.head(301)
# Out:
#                                       Classes Old Price  \
# 0         Peugeot 5008 A/T / Active Pack 2023   1029990
# 1      Ssang Yong Tivoli XLV A/T / Style 2023    675000
# 2    Ssang Yong Tivoli XLV A/T / Comfort 2023    605000
# 3     Ssang Yong Tivoli A/T / Style Plus 2023    665000
# 4        Ssang Yong Tivoli A/T / Comfort 2023    590000
# ..                                        ...       ...
# 296          Kaiyi X3 Pro A/T / FLAGSHIP 2022    399000
# 297            Kaiyi X3 Pro A/T / Luxury 2022    364000
# 298              Kaiyi X3 A/T / FlagShip 2022    349000
# 299              Kaiyi X3 A/T / Prestige 2022    319000
# 300  Citroën C4 A/T / Shine Red interior 2023    729900
#
#                  Price Change New Price change date
# 0    trending_up +110,000 EGP   1139990   1/19/2023
# 1      trending_up +5,000 EGP    680000   1/19/2023
# 2    trending_up +185,000 EGP    790000   1/19/2023
# 3    trending_up +185,000 EGP    850000   1/19/2023
# 4    trending_up +170,000 EGP    760000   1/19/2023
# ..                        ...       ...         ...
# 296  trending_up +251,000 EGP    650000   1/10/2023
# 297  trending_up +236,000 EGP    600000   1/10/2023
# 298  trending_up +216,000 EGP    565000   1/10/2023
# 299  trending_up +226,000 EGP    545000   1/10/2023
# 300  trending_up +135,100 EGP    865000   1/10/2023
#
# [301 rows x 5 columns]

# %% [markdown]
# ## Выведем график зависимости первых 25-и элементов (класс/новый прайс)
# ***
# * Мы можем увидеть, какие машины стоят дороже
# ****

# %%
sns.set(font_scale=0.8)
sns.lineplot(data=car,x = car["Classes"][0:25], y = car["New Price"][0:25]).tick_params(axis='x',rotation=75)
# Out:
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Проделывем тоже самое и со старым прайсом, чтобы также сравнить стоимость от класса(марки)
# ***

# %%
sns.set(font_scale=0.8)
sns.lineplot(data=car,x = car["Classes"][0:25], y = car["Old Price"][0:25]).tick_params(axis='x',rotation=75)
# Out:
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set(font_scale=0.8)
sns.lineplot(data=car,x = car["Classes"][0:25], y = car["Price Change"][0:25]).tick_params(axis='x',rotation=75)
# Out:
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# ## Средняя стоимость автомобиля по старому прайсу составляет примерно 598.272 EGP
# ***

# %%
car["Old Price"].mean()
# Out:
# 598272.8299086757

# %% [markdown]
# ## Средняя стоимость автомобиля по новому прайсу составляет примерно 649.551  EGP
# ****
# * Т.е это дороже, примерно на 51278.375 EGP*

# %%
car["New Price"].mean()
# Out:
# 649551.2049086757

# %%
car["New Price"].mean() - car["Old Price"].mean()
# Out:
# 51278.375

# %% [markdown]
# ## Теперь посмотрим общую стоимость всех машин по старому прайсу:
# ***

# %%
car["Old Price"].sum()
# Out:
# 2096347996

# %% [markdown]
# ## Т.е общая стоимость всех автомобилей по старому прайсу составляет 2.096.347.996
# ***

# %% [markdown]
# ## Выведем общую стоимость всех машин уже по новому прайсу:
# ***

# %%
car["New Price"].sum()
# Out:
# 2276027422

# %%
2276027422-2096347996
# Out:
# 179679426

# %% [markdown]
# ## Исходя из полученных данных мы видим, что общая стоимость всех автомобилей составляет 2.276.027.422 (по новому прайсу)
# * Т.е это на 179.679.426 дороже, чем стоимость по старой цене

# %% [markdown]
# ## Сортируем данные в алфавитном порядке в столбце "Classes"
# ****

# %%
car.sort_values('Classes')
# Out:
#                                      Classes Old Price  \
# 1634     Alfa Romeo Giulia A/T / Veloce 2022    920000
# 1631  Alfa Romeo Giulietta A/T / Veloce 2022    645000
# 1633     Alfa Romeo Stelvio A/T / Super 2022   1050000
# 1632    Alfa Romeo Stelvio A/T / Super+ 2022   1150000
# 410              Audi A3 A/T / Advanced 2022    990000
# ...                                      ...       ...
# 1623          Volvo XC60 A/T / R-Design 2022   1210000
# 644        Volvo XC90 A/T / Inscription 2022   1950000
# 1621       Volvo XC90 A/T / Inscription 2022   1600000
# 645           Volvo XC90 A/T / Momentum 2022   1770000
# 1622          Volvo XC90 A/T / Momentum 2022   1450000
#
#                   Price Change New Price change date
# 1634  trending_up +130,000 EGP   1050000   7/20/2022
# 1631    trending_up +5,000 EGP    650000   7/20/2022
# 1633  trending_up +100,000 EGP   1150000   7/20/2022
# 1632  trending_up +110,000 EGP   1260000   7/20/2022
# 410   trending_up +260,000 EGP   1250000  12/15/2022
# ...                        ...       ...         ...
# 1623  trending_up +280,000 EGP   1490000   7/20/2022
# 644   trending_up +700,000 EGP   2650000  11/15/2022
# 1621  trending_up +350,000 EGP   1950000   7/20/2022
# 645   trending_up +680,000 EGP   2450000  11/15/2022
# 1622  trending_up +320,000 EGP   1770000   7/20/2022
#
# [3504 rows x 5 columns]

# %%
car['Classes'].value_counts()
# Out:
# Classes
# Haval H6 A/T / Deluxe 2022                  18
# Haval H6 A/T / Deluxe SR 2022               18
# Haval H6 A/T / Standard 2022                18
# Haval H6 A/T / High Deluxe 2022             18
# Changan Alsvin A/T / L1 2022                17
#                                             ..
# Nissan Sentra Automatic / High Line 2022     1
# Nissan Sentra Automatic / BASIC 2022         1
# Ford Focus A/T / Titanium 4d 2023            1
# Ford Focus A/T / Connected 5d 2023           1
# Peugeot 5008 A/T / Active Pack 2023          1
# Name: count, Length: 550, dtype: int64

# %%
car['classes_count'] = car.groupby('Classes')['Classes'].transform('count')
car.sample(25)
# Out:
#                                                 Classes Old Price  \
# 2948                       Renault Duster A/T / H3 2022    343000
# 2777                     Hyundai Bayon A/T / Elite 2022    345000
# 576                    Renault Megane A/T / Vision 2022    494000
# 2354                         Citroën C3 A/T / Feel 2022    339900
# 2036                  Renault Megane A/T / Dynamic 2022    424000
# 1743                    Chery Tiggo 8 A/T / Luxury 2022    525000
# 1756  Hyundai Elantra HD Automatic / GL / DAB / ABS ...    337000
# 594                Jeep Renegade A/T / Limited 4WD 2022    630000
# 3438   Toyota Corolla Automatic / SMART / Sun Roof 2022    405000
# 1339                     Peugeot 508 A/T / GT Line 2022    754990
# 3296                         Haval H6 A/T / Deluxe 2022    405000
# 1240         Chery Tiggo 3 Automtic / Tinted Glass 2023    340000
# 1583                     Peugeot 508 A/T / GT Line 2022    739990
# 1848        Peugeot 508 A/T / GT Line Red Interior 2022    735990
# 3375            Hyundai Elantra CN7 A/T / ADVANCED 2022    430000
# 1933                  Chery Tiggo 7 A/T / Highline 2023    399900
# 790   Hyundai Elantra HD Automatic / GL / SR / TINTE...    400000
# 484                       Seat Leon A/T / ADVANCED 2022    410000
# 128                  MG HS Automatic / LFC Edition 2022    810000
# 837                         Honda Accord A/T / EXL 2022    780000
# 2865          Hyundai Elantra CN7 A/T / SMART PLUS 2022    387900
# 1873                     Haval Jolion A/T / Deluxe 2022    455000
# 2045                Renault Kadjar A/T / Signature 2022    530000
# 1454               Mercedes E 200 A/T / Cabrio AMG 2022   1790000
# 2405                           Jac JS3 A/T / Smart 2022    303000
#
#                   Price Change New Price change date  classes_count
# 2948    trending_up +9,000 EGP    352000    2/3/2022              7
# 2777   trending_up +35,000 EGP    380000   3/21/2022             11
# 576    trending_up +40,000 EGP    534000  11/24/2022              9
# 2354    trending_up +6,000 EGP    345900    5/1/2022              5
# 2036   trending_up +11,000 EGP    435000    6/2/2022              9
# 1743   trending_up +15,000 EGP    540000    7/2/2022             16
# 1756    trending_up +5,000 EGP    342000    7/2/2022             14
# 594   trending_up +220,000 EGP    850000  11/22/2022              2
# 3438   trending_up +12,000 EGP    417000   8/25/2021              5
# 1339   trending_up +15,000 EGP    769990   8/13/2022             10
# 3296    trending_up +5,000 EGP    410000   10/4/2021             18
# 1240   trending_up +20,000 EGP    360000    9/1/2022             13
# 1583   trending_up +15,000 EGP    754990   7/24/2022             10
# 1848   trending_up +10,000 EGP    745990   6/18/2022             10
# 3375    trending_up +3,000 EGP    433000   9/25/2021              9
# 1933    trending_up +7,100 EGP    407000   6/15/2022             13
# 790    trending_up +40,000 EGP    440000  10/31/2022             12
# 484   trending_up +380,000 EGP    790000   12/6/2022              3
# 128    trending_up +49,990 EGP    859990   1/15/2023             15
# 837   trending_up +180,000 EGP    960000  10/17/2022              4
# 2865    trending_up +2,100 EGP    390000    3/1/2022             10
# 1873    trending_up +5,000 EGP    460000   6/15/2022             16
# 2045   trending_up +20,000 EGP    550000    6/2/2022              7
# 1454  trending_up +160,000 EGP   1950000    8/2/2022              5
# 2405   trending_up +24,000 EGP    327000   4/21/2022             17

# %% [markdown]
# ## Из столбца "change date" выведем количество машин, выпущенных в определенном году

# %% [markdown]
# # 2023:
# ****
# #### =360 авт.

# %%
car['change date'][0:363].str.endswith('3')
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 358     True
# 359     True
# 360    False
# 361    False
# 362    False
# Name: change date, Length: 363, dtype: bool

# %% [markdown]
# # 2022:
# ****
# #### =2676 авт.

# %%
car['change date'][359:3038].str.endswith('2')
# Out:
# 359     False
# 360      True
# 361      True
# 362      True
# 363      True
#         ...
# 3033     True
# 3034     True
# 3035     True
# 3036    False
# 3037    False
# Name: change date, Length: 2679, dtype: bool

# %% [markdown]
# # 2021:
# ****
# #### =433 авт.

# %%
car['change date'][3035:3470].str.endswith('1')
# Out:
# 3035    False
# 3036     True
# 3037     True
# 3038     True
# 3039     True
#         ...
# 3465     True
# 3466     True
# 3467     True
# 3468     True
# 3469    False
# Name: change date, Length: 435, dtype: bool

# %% [markdown]
# # 2020:
# ***
# #### =31 авт.

# %%
car['change date'][3468:3501].str.endswith('0')
# Out:
# 3468    False
# 3469     True
# 3470     True
# 3471     True
# 3472     True
# 3473     True
# 3474     True
# 3475     True
# 3476     True
# 3477     True
# 3478     True
# 3479     True
# 3480     True
# 3481     True
# 3482     True
# 3483     True
# 3484     True
# 3485     True
# 3486     True
# 3487     True
# 3488     True
# 3489     True
# 3490     True
# 3491     True
# 3492     True
# 3493     True
# 3494     True
# 3495     True
# 3496     True
# 3497     True
# 3498     True
# 3499     True
# 3500    False
# Name: change date, dtype: bool

# %% [markdown]
# # 2019
# ****
# #### =4 авт.

# %%
car['change date'].str.endswith('9')
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3499    False
# 3500     True
# 3501     True
# 3502     True
# 3503     True
# Name: change date, Length: 3504, dtype: bool

# %% [markdown]
# # Выведем процентное соотношение количества машин, выпущенных в определенных годах

# %%
data = [360, 4, 2676, 433, 31]
labels = ["2023","2019", "2022", "2021", "2020"]
colors = sns.color_palette('bright')[4:9]
plt.pie(data, labels = labels, colors = colors, autopct='%.0f%%')
plt.show()

# %% [markdown]
# ## Можем сделать следующий вывод:
# * в 2022 году было выпущенно наибольшее количество машин (2676 = 76%)
# * в 2019 и в 2020 выпущено наименьшее число автомобилей (примерно по 1%)
# * в 2023 и 2021 выпущено примерно одинаковое кол-во (10-12%)
