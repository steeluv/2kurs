# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
import pandas as pd
import seaborn as sns

# %%
car = pd.read_csv("C:\\Users\\Steluv\\PycharmProjects\\pythonProject8\\venv\\car.csv",delimiter=",")

# %%
car
# Out:
#                                              Unnamed: 0  Classes  Old Price  \
# 0     0,Peugeot 5008 A/T / Active Pack 2023,"1,029,9...      NaN        NaN
# 1     1,Ssang Yong Tivoli XLV A/T / Style 2023,"675,...      NaN        NaN
# 2     2,Ssang Yong Tivoli XLV A/T / Comfort 2023,"60...      NaN        NaN
# 3     3,Ssang Yong Tivoli A/T / Style Plus 2023,"665...      NaN        NaN
# 4     4,Ssang Yong Tivoli A/T / Comfort 2023,"590,00...      NaN        NaN
# ...                                                 ...      ...        ...
# 3499  3499,Lexus LX 570 Automtic 2020,"5,600,000 EGP...      NaN        NaN
# 3500  3500,Lexus ES 350 Automtic 2020,"2,650,000 EGP...      NaN        NaN
# 3501  3501,Lexus LX 570 Automtic 2020,"5,800,000 EGP...      NaN        NaN
# 3502  3502,Porsche Cayenne A/T / S 2020,"2,262,876 E...      NaN        NaN
# 3503  3503,Porsche Cayenne A/T / Coupe 2020,"2,078,7...      NaN        NaN
#
#       Price Change  New Price  date_range
# ...
