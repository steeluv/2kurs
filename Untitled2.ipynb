# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv(r"C:\\Users\\Steluv\\Downloads\\Titanic.csv")

# %%
titanic.drop(['Name','Ticket','Cabin'], axis = 1)
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch     Fare  \
# 0              1         0       3    male  22.0      1      0   7.2500
# 1              2         1       1  female  38.0      1      0  71.2833
# 2              3         1       3  female  26.0      0      0   7.9250
# 3              4         1       1  female  35.0      1      0  53.1000
# 4              5         0       3    male  35.0      0      0   8.0500
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0  13.0000
# 887          888         1       1  female  19.0      0      0  30.0000
# 888          889         0       3  female   NaN      1      2  23.4500
# 889          890         1       1    male  26.0      0      0  30.0000
# 890          891         0       3    male  32.0      0      0   7.7500
#
#     Embarked
# 0          S
# 1          C
# 2          S
# 3          S
# 4          S
# ..       ...
# ...

# %%
titanic['Age'].fillna(titanic['Age'].mean())
# Out:
# 0      22.000000
# 1      38.000000
# 2      26.000000
# 3      35.000000
# 4      35.000000
#          ...
# 886    27.000000
# 887    19.000000
# 888    29.699118
# 889    26.000000
# 890    32.000000
# Name: Age, Length: 891, dtype: float64

# %%
sns.lineplot(data = titanic, x = "PassengerId", y = "Age")
# Out:
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
data = [644, 168, 77]
labels = ['S', 'C', 'Q']
colors = sns.color_palette('bright')[6:10]
plt.pie(data, labels = labels, colors = colors, autopct ='%0f%%')
plt.show()

# %%
sns.lineplot(data = titanic, x = 'Embarked', y = 'Fare')
# Out:
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
sns.barplot(data = titanic, x = 'Embarked', y = 'Age')
# Out:
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\Steluv\PycharmProjects\pythonProject8\venv\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
data = [233, 109]
labels = ['female', 'male']
colors = sns.color_palette('bright')[6:10]
plt.pie(data, labels = labels, colors = colors, autopct ='%0f%%')
plt.show()
data = [81, 468]
labels = ['not survived female', 'not survived male']
colors = sns.color_palette('bright')[6:10]
plt.pie(data, labels = labels, colors = colors, autopct ='%0f%%')
plt.show()

# %%
titanic.Survived[titanic.Survived == 1][titanic.Sex == 'female'].count()
# Out:
# 233

# %%
titanic.Survived[titanic.Survived == 1][titanic.Sex == 'male'].count()
# Out:
# 109

# %%
titanic.Survived[titanic.Survived == 0][titanic.Sex == 'female'].count()
# Out:
# 81

# %%
titanic.Survived[titanic.Survived == 0][titanic.Sex == 'male'].count()
# Out:
# 468
